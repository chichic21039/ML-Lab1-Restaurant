# %%
pip install img2pdf
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 16.3 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [pikepdf]
#    ------------- -------------------------- 1/3 [pikepdf]
#    ------------- -------------------------- 1/3 [pikepdf]
#    ------------- -------------------------- 1/3 [pikepdf]
#    ------------- -------------------------- 1/3 [pikepdf]
#    ------------- -------------------------- 1/3 [pikepdf]
#    -------------------------- ------------- 2/3 [img2pdf]
#    -------------------------- ------------- 2/3 [img2pdf]
#    ---------------------------------------- 3/3 [img2pdf]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# ...

# %%
import img2pdf
from PIL import Image
import os

def png_to_pdf(input_path, output_path):
    print(f"--- Đang chuyển {input_path} sang PDF ---")
    # Đảm bảo file tồn tại
    if not os.path.exists(input_path):
        print("Lỗi: Không tìm thấy file đầu vào!")
        return

    # Chuyển đổi sang PDF
    with open(output_path, "wb") as f:
        f.write(img2pdf.convert(input_path))
    
    print(f"Hoàn thành! File PDF lưu tại: {output_path}")

# Sử dụng
png_to_pdf("matrices.png", "matrices.pdf")
# Out:
# Image contains an alpha channel. Computing a separate soft mask (/SMask) image to store transparency in PDF.
# --- Đang chuyển matrices.png sang PDF ---
# Hoàn thành! File PDF lưu tại: matrices.pdf
